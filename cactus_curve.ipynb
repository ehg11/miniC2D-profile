# %%
# load the data
import os

import pandas as pd

from analysis import load_data
from config import STATS_DIR

stats = []
for f in os.listdir(STATS_DIR):
    if not f.endswith(".json"):
        continue
    basename = os.path.basename(f)
    json_data = load_data(f"{STATS_DIR}{f}")
    if "compile_time" not in json_data:
        json_data["compile_time"] = json_data["total_time"]

    json_data["cnf"] = basename
    stats.append(json_data)

df = pd.DataFrame(stats)

# remove 0 columns
df = df.loc[:, (df != 0).any(axis=0)]

df = df.sort_values("total_time", ascending=False).reset_index(drop=True)

df
# Out:
#     total_time  sat_is_instantiated_var  sat_is_irrelevant_var  \
# 0     1380.919                34.153596               0.074540
# 1     1245.095                 0.169409               0.119198
# 2      727.703                20.560665               0.296785
# 3      453.189                 2.641139               0.117767
# 4      374.828                 9.256477               0.170710
# 5      171.751                 2.635861               0.102701
# 6      159.200                 0.966498               0.116048
# 7      152.140                 0.209100               0.024405
# 8      143.747                 0.471292               0.042859
# 9      142.537                 0.889606               0.044765
# 10     107.203                 0.079623               0.001841
# 11     102.655                 0.970167               0.003880
# 12     102.501                 0.296552               0.045511
# 13      48.377                 0.000877               0.000029
# ...

# %%
# make the cactus plot
import matplotlib.pyplot as plt

benchmarks_solved = range(len(df), 0, -1)

plt.figure(figsize=(10, 10))
plt.plot(benchmarks_solved, df["total_time"], label="miniC2D", marker='o')

plt.xlabel("Benchmarks solved")
plt.ylabel("Time (s)")
plt.title("Cactus plot of miniC2D performance")
plt.show()
